# %%
from axifem import*

# %%
nodes,elem,bced,pn = readMsh4_1('veggur.msh')
x,y,tri,T,V,q = axiHeatCond('veggur.msh',{'ribba':16},{'ytri':(45,-13095),'innri':(1200,-441600),'einangrun':(0,0)})

# %%
from matplotlib.pyplot import*
tricontourf(x,y,tri,T,50)
axis('equal')
show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q
# Out:
# {'ytri': [7.853981633974481e-05, 0.26018807095314456],
#  'einangrun': [9.424777960769383e-05, 0.0],
#  'innri': [7.853981633974483e-05, -0.26018807095288676]}
