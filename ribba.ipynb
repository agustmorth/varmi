# %%
from axifem import*

# %%
nodes,elem,bced,pn = readMsh4_1('ribba.msh')
x,y,tri,T,V,q = axiHeatCond('ribba.msh',{'ribba':16},{'ytri':(45,-13095),'innri':(1200,-441600),'einangrun':(0,0)})

# %%
from matplotlib.pyplot import*
tricontourf(x,y,tri,T,50)
axis('equal')
show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
